# %%
import pandas as pd

# %%
df = pd.read_csv('results/Color Accuracy Results.csv')

# %%
df.drop('Model', axis=1)
# Out:
#     Convolution Layers  Layer Size  Dense Layers  Training Loss  \
# 0                    1          32             0         0.0478
# 1                    1          32             1         0.0435
# 2                    1          32             2         0.0646
# 3                    1          64             0         0.0450
# 4                    1          64             1         0.0420
# 5                    1          64             2         0.0216
# 6                    1         128             0         0.0559
# 7                    1         128             1         0.0220
# 8                    1         128             2         0.0126
# 9                    2          32             0         0.1392
# 10                   2          32             1         0.1585
# 11                   2          32             2         0.0848
# 12                   2          64             0         0.0535
# 13                   2          64             1         0.0944
# 14                   2          64             2         0.0430
# 15                   2         128             0         0.1268
# 16                   2         128             1         0.0456
# 17                   2         128             2         0.0572
# 18                   4          32             0         0.0633
# 19                   4          32             1         0.1370
# 20                   4          32             2         0.1061
# 21                   4          64             0         0.0528
# 22                   4          64             1         0.0879
# 23                   4          64             2         0.0716
# 24                   4         128             0         0.0567
# 25                   4         128             1         0.0382
# 26                   4         128             2         0.0792
#
#     Training Accuracy  Validation Loss  Validation Accuracy  Testing Accuracy
# 0              0.9903           0.4341               0.8879             89.92
# 1              0.9914           0.4640               0.8836             86.82
# 2              0.9806           0.6160               0.8276             89.15
# 3              0.9925           0.5594               0.8685             87.21
# 4              0.9914           0.5385               0.8815             89.53
# 5              0.9930           0.6168               0.8707             86.43
# 6              0.9865           0.5814               0.8427             86.43
# 7              0.9930           0.6282               0.8772             89.92
# 8              0.9925           0.7766               0.8772             87.21
# 9              0.9623           0.8286               0.8362             83.72
# 10             0.9510           0.7748               0.8254             82.17
# 11             0.9644           0.8586               0.8147             81.78
# 12             0.9865           0.7298               0.8750             86.43
# 13             0.9682           1.7890               0.7371             72.48
# 14             0.9865           0.8425               0.8879             86.82
# 15             0.9768           1.1906               0.8039             81.40
# 16             0.9881           0.7182               0.8793             87.60
# 17             0.9811           0.8432               0.8621             87.21
# 18             0.9838           0.3340               0.9052             91.86
# 19             0.9537           0.6439               0.8297             75.97
# 20             0.9574           0.4842               0.8944             87.60
# 21             0.9855           0.3382               0.9030             88.76
# 22             0.9698           1.1993               0.7091             71.71
# 23             0.9736           0.5064               0.8750             83.33
# 24             0.9860           0.2635               0.9397             91.86
# 25             0.9860           0.8226               0.8341             86.05
# 26             0.9741           0.3973               0.9030             93.04

# %%
variable_combinations = df[['Convolution Layers', 'Dense Layers', 'Layer Size']]
variable_combinations.drop_duplicates()
# Out:
#     Convolution Layers  Dense Layers  Layer Size
# 0                    1             0          32
# 9                    2             0          32
# 18                   4             0          32

# %%
settings_df = pd.DataFrame(columns=['Convolution Layers', 'Dense Layers', 'Layer Size'])
settings_df = settings_df.append({'Convolution Layers':1, 'Dense Layers':0, 'Layer Size':32}, ignore_index=True)
settings_df = settings_df.append({'Convolution Layers':2, 'Dense Layers':1, 'Layer Size':64}, ignore_index=True)
settings_df = settings_df.append({'Convolution Layers':4, 'Dense Layers':2, 'Layer Size':128}, ignore_index=True)
settings_df
# Out:
#   Convolution Layers Dense Layers Layer Size
# 0                  1            0         32
# 1                  2            1         64
# 2                  4            2        128

# %%
def highlight_max(s):
    '''
    highlight the maximum in a Series yellow.
    '''
    is_max = s == s.max()
    return ['background-color: yellow' if v else '' for v in is_max]

# %%
grouped_df = df.drop(['Dense Layers', 'Layer Size'], axis=1).groupby(['Convolution Layers']).mean()
grouped_df.style.apply(highlight_max, subset=['Testing Accuracy'])
# Out:
# <style  type="text/css" >
#     #T_73ccd9c0_17ea_11ea_b90b_acde48001122row0_col4 {
#             background-color:  yellow;
#         }</style><table id="T_73ccd9c0_17ea_11ea_b90b_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Training Loss</th>        <th class="col_heading level0 col1" >Training Accuracy</th>        <th class="col_heading level0 col2" >Validation Loss</th>        <th class="col_heading level0 col3" >Validation Accuracy</th>        <th class="col_heading level0 col4" >Testing Accuracy</th>    </tr>    <tr>        <th class="index_name level0" >Convolution Layers</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_73ccd9c0_17ea_11ea_b90b_acde48001122level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_73ccd9c0_17ea_11ea_b90b_acde48001122row0_col0" class="data row0 col0" >0.0394444</td>
#                         <td id="T_73ccd9c0_17ea_11ea_b90b_acde48001122row0_col1" class="data row0 col1" >0.990133</td>
#                         <td id="T_73ccd9c0_17ea_11ea_b90b_acde48001122row0_col2" class="data row0 col2" >0.579444</td>
#                         <td id="T_73ccd9c0_17ea_11ea_b90b_acde48001122row0_col3" class="data row0 col3" >0.868544</td>
#                         <td id="T_73ccd9c0_17ea_11ea_b90b_acde48001122row0_col4" class="data row0 col4" >88.0689</td>
#             </tr>
#             <tr>
#                         <th id="T_73ccd9c0_17ea_11ea_b90b_acde48001122level0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_73ccd9c0_17ea_11ea_b90b_acde48001122row1_col0" class="data row1 col0" >0.0892222</td>
#                         <td id="T_73ccd9c0_17ea_11ea_b90b_acde48001122row1_col1" class="data row1 col1" >0.973878</td>
#                         <td id="T_73ccd9c0_17ea_11ea_b90b_acde48001122row1_col2" class="data row1 col2" >0.952811</td>
#                         <td id="T_73ccd9c0_17ea_11ea_b90b_acde48001122row1_col3" class="data row1 col3" >0.835733</td>
#                         <td id="T_73ccd9c0_17ea_11ea_b90b_acde48001122row1_col4" class="data row1 col4" >83.29</td>
#             </tr>
#             <tr>
#                         <th id="T_73ccd9c0_17ea_11ea_b90b_acde48001122level0_row2" class="row_heading level0 row2" >4</th>
#                         <td id="T_73ccd9c0_17ea_11ea_b90b_acde48001122row2_col0" class="data row2 col0" >0.0769778</td>
#                         <td id="T_73ccd9c0_17ea_11ea_b90b_acde48001122row2_col1" class="data row2 col1" >0.974433</td>
#                         <td id="T_73ccd9c0_17ea_11ea_b90b_acde48001122row2_col2" class="data row2 col2" >0.554378</td>
#                         <td id="T_73ccd9c0_17ea_11ea_b90b_acde48001122row2_col3" class="data row2 col3" >0.865911</td>
#                         <td id="T_73ccd9c0_17ea_11ea_b90b_acde48001122row2_col4" class="data row2 col4" >85.5756</td>
#             </tr>
#     </tbody></table>
